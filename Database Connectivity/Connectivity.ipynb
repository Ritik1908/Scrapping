# %%
import mysql.connector

# %%
mydb=mysql.connector.connect
    host="IP Address of database",
    user="root",
    passwd="Password",
    database="Name Of Database"
)

# %%
# Cursor Object
mycursor=mydb.cursor()

# %%
# Fetching data from user table

mycursor.execute("SELECT * FROM users;")
mycursor.fetchall()
# Out:
# [(1,
#   1,
#   'Durga',
#   'Agarwal',
#   'durgaa219@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image1.jpg',
#   'UEM, Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/durgaag',
#   'https://medium.com/@durgaa219',
#   'https://sites.google.com/view/durgaag-portfolio/home',
#   'https://www.linkedin.com/in/durga-agarwal-52824218b',
#   'yTv0fB3WJA4',
#   'NA'),
#  (2,
#   1,
#   'Sharika',
#   'Anjum Mondal',
#   'sharikaanjumm@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Amity University, Kolkata',
#   2022,
#   'ECE',
#   'https://github.com/sharika-anjum',
#   'https://medium.com/@sharikaanjumm',
#   'https://sites.google.com/view/sharikas-portfolio',
#   'https://www.linkedin.com/in/sharika-anjum-mondal-8b80a3188',
#   '4egY7Fw2eqQ',
#   'NA'),
#  (3,
#   1,
#   'Swaastick',
#   'Singh',
#   'meightpc@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Amity University, Kolkata',
#   2022,
#   'CSE',
#   'https://github.com/mightomi',
#   'https://medium.com/@meightpc_14421',
#   'https://sites.google.com/view/meight/home',
#   'https://www.linkedin.com/in/swaastick/',
#   'e6Wl1q5SeqI',
#   'NA'),
#  (5,
#   1,
#   'Purbita',
#   'Sur',
#   'purbita1998@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image5.jpg',
#   'Amity University, Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/purbita-sur',
#   'https://medium.com/@purbita1998',
#   'https://sites.google.com/view/purbitasur/home',
#   'https://www.linkedin.com/in/purbita-sur',
#   '-OGeu5RQ00w',
#   'NA'),
#  (6,
#   1,
#   'Dipam',
#   'Hazra',
#   'dipamhazra1999@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   "St. Thomas' College of Engineering and Technology",
#   2021,
#   'CSE',
#   'https://github.com/DIPAM9',
#   'https://medium.com/@dipamhazra1999',
#   'https://www.dipamhazra.site',
#   'https://www.linkedin.com/in/dipam-hazra-71743218b',
#   'Y5WOLp17yRo',
#   'NA'),
#  (8,
#   1,
#   'Anjali',
#   '',
#   'anjaliksahar@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Adamas University',
#   2021,
#   'CSE',
#   'https://github.com/Anjalik25',
#   'https://medium.com/@anjaliksahar',
#   'https://sites.google.com/s/1FxQkAHjDsJHyzPiFIKT9Uuzz_oh0PIMp/p/1mY8koIwv3Ajka3Lzznrp4lUE92KgzvFC/edit',
#   'https://www.linkedin.com/in/anjali-687956156/',
#   'rIbgSprkO7I',
#   'NA'),
#  (9,
#   1,
#   'Bhavna',
#   'Kumari',
#   'bhavnagupta0103@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image9.jpg',
#   'Adamas University',
#   2021,
#   'CSE',
#   'https://github.com/bhavnakumari',
#   'https://medium.com/@bhavnagupta0103',
#   'https://sites.google.com/view/bhavna-kumari/home',
#   'https://www.linkedin.com/in/bhavna-kumari-4b671a182/',
#   '',
#   'NA'),
#  (10,
#   1,
#   'Arya',
#   'Sarkar',
#   'neelarya80@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'UEM, Kolkata',
#   2022,
#   'CSE',
#   'https://github.com/kindler-king',
#   'https://medium.com/@neelarya80',
#   'https://www.aryasarkar.info/',
#   'https://www.linkedin.com/in/arya-sarkar-78831782/',
#   '1lhRBMZ4gqM',
#   'NA'),
#  (11,
#   1,
#   'Sushree',
#   'Siddhishikha',
#   'siddhishikha1998@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Amity University, Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/siddhishikha1998',
#   'https://medium.com/@siddhishikha1998',
#   'https://sites.google.com/view/siddhishikha1998/home',
#   'https://www.linkedin.com/in/sushree-siddhishikha-6b942118b',
#   'A3H2El511x4',
#   'NA'),
#  (12,
#   1,
#   'Vishal',
#   'Malo',
#   'vishalmalo272000@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image12.png',
#   'GCELT, Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/Vishal-Malo',
#   'https://medium.com/@vishalmalo272000',
#   'https://www.vishalmalo.site/',
#   'https://www.linkedin.com/in/vishal-malo',
#   'SreaVCTEbXM',
#   'NA'),
#  (13,
#   1,
#   'Prasoon',
#   'Thakur',
#   'prasoonthakur5@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image13.jpg',
#   'GNIT, Sodepur',
#   2021,
#   'IT',
#   'https://github.com/PrasoonThakur5',
#   'https://medium.com/@prasoonthakur5',
#   'https://www.prasoonthakur.co',
#   'https://www.linkedin.com/in/prasoon-thakur-3bb74611b',
#   '',
#   'NA'),
#  (14,
#   1,
#   'Surabhi',
#   'Basak',
#   '2titi4@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image14.jpg',
#   'Amity University, Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/Surabhi-Basak',
#   'https://medium.com/@2titi4',
#   'https://sites.google.com/view/surabhi-basak/',
#   'https://www.linkedin.com/in/surabhi-basak/',
#   'WjORUa61SSc',
#   'NA'),
#  (15,
#   1,
#   'Kunal',
#   'N. Gohrani',
#   'gohranikunal25@outlook.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Amity University, Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/kunal-gohrani',
#   'https://medium.com/@kunal_gohrani',
#   'https://www.kunalgohrani.info/',
#   'https://www.linkedin.com/in/kunal-gohrani/',
#   'Tdn-j3Xn2jI',
#   'NA'),
#  (16,
#   1,
#   'Shakib',
#   'Mondal',
#   'sakibmondal7@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image16.jpg',
#   'GCELT, Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/SkeyRahaman',
#   'https://medium.com/@shakibmondal',
#   'https://www.mdshakibmondal.site',
#   'https://www.linkedin.com/in/shakib-mondal/',
#   'XuVuEyRu3MI',
#   'NA'),
#  (17,
#   1,
#   'Shantanu',
#   'Shubham',
#   'shantanu0707@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image17.jpg',
#   'BIT, Sindri',
#   2021,
#   'IT',
#   'https://github.com/shantnushubham',
#   'https://medium.com/@shantanu0707',
#   'https://sites.google.com/view/shantanushubham',
#   'https://www.linkedin.com/in/shantanushubham',
#   'Uvgh-9BFqfw',
#   'NA'),
#  (18,
#   1,
#   'Chandrima',
#   'Sarkar',
#   'sarkarchandrima12@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image18.jpeg',
#   'HETC, Hoogly',
#   2021,
#   'ECE',
#   'https://github.com/chandrimahere',
#   'https://medium.com/@sarkarchandrima12',
#   'https://sites.google.com/view/chandrimahere/home',
#   'https://www.linkedin.com/in/chandrima-sarkar-89242218b/',
#   'qJr7wrgAbLs',
#   'NA'),
#  (19,
#   1,
#   'Kaushal',
#   'Agarwal',
#   'kaushal.uemk@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'UEM, Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/kaushalaga',
#   'https://medium.com/@kaushal.uemk',
#   'https://www.kaushalagarwal.info/',
#   'https://www.linkedin.com/in/kaushal-agarwal-15b086183',
#   'TbbW8axpgeE',
#   'NA'),
#  (20,
#   1,
#   'Roumyak',
#   'Biswas',
#   'biswas.roumyak49@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'UEM, Kolkata',
#   2020,
#   'CSE',
#   'https://github.com/Roumyak49',
#   'https://medium.com/@roumyak.biswas',
#   'https://www.roumyakbiswas.me/',
#   'https://www.linkedin.com/in/roumyak-biswas-8aa50718b',
#   'EPQgg-m-jMI',
#   'NA'),
#  (21,
#   1,
#   'Ujjainee',
#   'De',
#   'bibide06@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Amity University, Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/ujjaineede',
#   'https://medium.com/@ujjainee',
#   'https://sites.google.com/view/ujjaineede/home',
#   'https://www.linkedin.com/in/ujjaineede/',
#   'tNfFogZGTpo',
#   'NA'),
#  (24,
#   2,
#   'Adarsh',
#   'Raj',
#   'adarshrajsv@gmail.com',
#   '6209708622',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image24.jpg',
#   'HIT, Haldia',
#   2022,
#   'IT',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (25,
#   2,
#   'Aditya',
#   'Raj',
#   'aditya2013raj01@gmail.com',
#   '9102970845',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image25.jpg',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   'https://github.com/adityaraaz01',
#   'https://medium.com/@aditya2013raj01',
#   'https://sites.google.com/view/adityaraj-info',
#   'https://www.linkedin.com/in/aditya-raaz01/',
#   '',
#   'NA'),
#  (29,
#   2,
#   'Aryan',
#   'Kumar Singh',
#   'aryanvikas007@gmail.com',
#   '9135364584',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'IT',
#   'https://github.com/fiercearyan',
#   'https://medium.com/@aryanvikas007',
#   '',
#   'https://www.linkedin.com/in/aryan-singh-54a1a0175',
#   '',
#   'NA'),
#  (31,
#   2,
#   'Dhananjay',
#   'Kumar',
#   '99dhananjay@gmail.com ',
#   '6206014501',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'IT',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (32,
#   2,
#   'Harshit',
#   'Kumar',
#   'harshit3551@gmail.com',
#   '7903077184',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'ECE',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (33,
#   2,
#   'Harshita',
#   'Singh',
#   'harshita.official99@gmail.com',
#   '7896534656',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (34,
#   2,
#   'Himanshu',
#   'Raj',
#   'rajh91774@gmail.com',
#   '9083775974',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (36,
#   2,
#   'Koushik',
#   'Duari',
#   'duarikoushik@gmail.com',
#   '7478957418',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   'https://github.com/Kd2706',
#   'https://medium.com/me/stories/public',
#   'https://sites.google.com/view/koushikduari/home',
#   'https://www.linkedin.com/in/koushik-duari-b12a66186/',
#   '',
#   'NA'),
#  (38,
#   2,
#   'Sumanta',
#   'Mandal',
#   'mr.sumantamandal@gmail.com',
#   '7548079157',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   'https://github.com/smn007',
#   'https://medium.com/@mr.sumantamandal',
#   'https://www.sumantamandal.info',
#   'https://www.linkedin.com/in/sumantamandal01',
#   '',
#   'NA'),
#  (39,
#   2,
#   'Rahul',
#   'Kumar',
#   '353rahulkumar@gmail.com',
#   '7463971600',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image39.jpg',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   'https://github.com/rahulkumar353',
#   'https://medium.com/@353rahulkumar',
#   'https://sites.google.com/view/rahul-resume/home',
#   'http://www.linkedin.com/in/rahul-kumar-ba015816b',
#   '',
#   'NA'),
#  (40,
#   2,
#   'Rahul',
#   'Mondal',
#   'rahulmondalhit@gmail.com',
#   '9382086446',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'ECE',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (41,
#   2,
#   'Ravi',
#   'Kumar',
#   'Ravikmr0031@gmail.com',
#   '7667620035',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'ECE',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (42,
#   2,
#   'Kumar',
#   'Shubham',
#   'skraj7177448@gmail.com',
#   '8507474116',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'MECH',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (43,
#   2,
#   'Saurabh',
#   'Kumar',
#   'kumarsaurabh614@gmail.com',
#   '8804882773',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   'https://github.com/kumarsaurabh614',
#   'https://medium.com/@kumarsaurabh614',
#   'https://sites.google.com/view/saurabh-portfolio/home',
#   'https://www.linkedin.com/in/saurabh-kumar-49a066194',
#   '',
#   'NA'),
#  (44,
#   2,
#   'Shiv',
#   'Prakash',
#   'shivpr06@gmail.com',
#   '9060360890',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'IT',
#   'https://github.com/Shivpr04',
#   'https://medium.com/@shivpr06',
#   '',
#   'https://www.linkedin.com/in/shiv-prakash-986880193',
#   '',
#   'NA'),
#  (45,
#   2,
#   'Shivam',
#   'Patel',
#   '8987495865shivam@gmail.com',
#   '8695326743',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2015,
#   'CSE',
#   'https://github.com/ShivamPatel1999',
#   'https://medium.com/@8987495865shivam',
#   '',
#   'https://www.linkedin.com/in/shivam-patel-1b7b30193',
#   '',
#   'NA'),
#  (46,
#   2,
#   'Shivendra',
#   'Shivam',
#   'shivendrashivam02kr@gmail.com',
#   '8757451197',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'ECE',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (47,
#   2,
#   'Shruti',
#   'Kumari',
#   'shrutisingh2085@gmail.com',
#   '6203282085',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (48,
#   2,
#   'Shubham',
#   'Jha',
#   'kumarshubham853904@gmail.com',
#   '8539040596',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image48.jpg',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'NA'),
#  (49,
#   2,
#   'Shubham',
#   'Kumar Raj',
#   '143jshubham@gmail.com',
#   '9123164681',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'IT',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (50,
#   2,
#   'Shubham',
#   'Kumar',
#   'shubham21101997@gmail.com',
#   '7079073396',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (51,
#   2,
#   'Soumyadeep',
#   'Hore',
#   'soumyadeephore9@gmail.com',
#   '9903191681',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'HIT, Haldia',
#   2022,
#   'CSE',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (52,
#   2,
#   'Suman',
#   'Kumar Suman',
#   'samp.suman@gmail.com',
#   '8873332177',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image52.jpg',
#   'HIT, Haldia',
#   2022,
#   'CE',
#   'https://github.com/samp-suman',
#   'https://medium.com/@samp.suman',
#   '',
#   'https://www.linkedin.com/in/samp-suman/',
#   '',
#   'NA'),
#  (53,
#   2,
#   'Surjayan',
#   'Dutta',
#   'hit18ee.surjayan@gmail.com',
#   '7718595554',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image53.jpg',
#   'HIT, Haldia',
#   2022,
#   'EE',
#   'https://github.com/surjayan12345',
#   ' https://link.medium.com/9WYDycHux3',
#   'https://sites.google.com/view/surjayandutta/home?authuser=0',
#   'https://www.linkedin.com/in/surjayan-dutta-48604b17a',
#   '',
#   'NA'),
#  (56,
#   1,
#   'Nitish',
#   'Singh',
#   'test@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image56.jpg',
#   'BIT Mesra',
#   2015,
#   'CSE',
#   'https://github.com/campusx-official',
#   'https://www.medium.in/nitish24singh',
#   'https://portfolio.in',
#   'https://www.linkedin.in',
#   '2Oy4HpUJSgE',
#   'NA'),
#  (66,
#   1,
#   'abc',
#   'pqr',
#   'test1@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image66.jpg',
#   'mera college',
#   2020,
#   'ESE',
#   'https://www.github.com',
#   'https://www.google.com/',
#   'https://www.google.com/',
#   'https://www.google.com/',
#   None,
#   'NA'),
#  (67,
#   3,
#   'Tathagata',
#   'Nath',
#   'tathagatanath99@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image67.jpg',
#   'Techno International, Newtown',
#   2021,
#   'BCA',
#   'https://github.com/TathagataNath/TATHAGATA_NATH',
#   'https://www.medium.com/@tathagatanath99',
#   'https://sites.google.com/view/tathagatanath/home',
#   'https://www.linkedin.com/in/tathagata-nath-0b916a191',
#   '',
#   'U010T9HURNV'),
#  (68,
#   3,
#   'Tuhin',
#   'Mukherjee',
#   'tuhinmukherjee744@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Hoogly Engineering And Technology College',
#   2015,
#   'CSE',
#   'https://github.com/whitexgod',
#   'https://medium.com/@tuhinmukherjee74',
#   'https://sites.google.com/view/tuhins-portfolio/home?authuser=2',
#   'https://www.linkedin.com/in/tuhin-mukherjee-38376219b/',
#   'Y4c3G6JLotc',
#   'U010RRQLA0K'),
#  (69,
#   3,
#   'Sumantra',
#   'Pal',
#   'sumantrapal34@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'KIIT UNIVERSITY',
#   2015,
#   'CSE',
#   'https://github.com/SumantraPal',
#   'https://medium.com/@sumantrapal34',
#   'https://sites.google.com/view/sumantrasportfolio/home?authuser=0',
#   'https://www.linkedin.com/in/sumantra-pal-276444182/',
#   '',
#   'U01156TJ9K8'),
#  (70,
#   3,
#   'Sagar',
#   'Sarkar',
#   'sagar1999sarkarcse@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image70.jpeg',
#   'Techno main salt lake',
#   2022,
#   'CSE',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'U010RRQPFPD'),
#  (71,
#   3,
#   'Soumyajyoti',
#   'Karmakar',
#   'ksoumyajyoti@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image71.png',
#   'E',
#   2022,
#   'CSE',
#   'https://github.com/soumyajyotigit',
#   'https://medium.com/@ksoumyajyoti',
#   '',
#   'https://www.linkedin.com/in/soumyajyoti-karmakar-732890159',
#   '',
#   'U0112R9BM6G'),
#  (72,
#   3,
#   'Suman',
#   'Das',
#   'imsumand@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Future Institute of Engineering & Management',
#   2019,
#   'CSE',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'U0115B4SFRV'),
#  (73,
#   3,
#   'Dilshad',
#   'Hussain',
#   'dilshadhussain576@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'U010T9HTYEM'),
#  (74,
#   3,
#   'Wasif',
#   'Ekbal',
#   'wasifekbal27@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'U01138MS5E1'),
#  (75,
#   3,
#   'Ritwik',
#   'Ghosh',
#   'ritwik.ghosh1010@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image75.jpg',
#   'Amity University Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/ritwik-ghosh153',
#   'https://medium.com/@ritwik.ghosh1010',
#   'https://ritwik-ghosh153.github.io',
#   'https://www.linkedin.com/in/ritwik-ghosh-01ba01152/',
#   'vesv2lXOe-U',
#   'U010T9HLE9X'),
#  (76,
#   3,
#   'Ritik',
#   'Verma',
#   'ritikverma8100775754@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image76.jpg',
#   'Amity University, Kolkata',
#   2021,
#   'CSE',
#   'https://github.com/Ritik1908',
#   '',
#   'https://ritik1908.github.io/',
#   'https://www.linkedin.com/in/ritik-v-100516a5/',
#   '',
#   'U0113A8TVJL'),
#  (77,
#   3,
#   'Rajtilak',
#   'Pal',
#   'rajtilakls2510@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image77.jpg',
#   'Techno Main Salt Lake',
#   2022,
#   'CSE',
#   'https://github.com/rajtilakls2510',
#   'https://medium.com/@rajtilakls2510',
#   'https://sites.google.com/view/rajtilak-pal-portfolio-website/home',
#   'https://www.linkedin.com/in/rajtilak-pal-5a78b7192',
#   'T-Dqt8GAj7A',
#   'U010ZGUR485'),
#  (78,
#   3,
#   'Balaka',
#   'Biswas',
#   'balaka2605@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image78.jpg',
#   'Institute Of Engineering & Management , Kolkata',
#   2022,
#   'CSE',
#   'https://github.com/BALaka-18',
#   'https://medium.com/@balaka2605',
#   'https://sites.google.com/view/balakabiswas',
#   'https://www.linkedin.com/in/balaka-biswas-898492185/',
#   '_HEEXUiyCQE',
#   'U010T9HVD7T'),
#  (79,
#   3,
#   'Srinjoy',
#   'Chowdhury',
#   'srinjoy35@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image79.jpg',
#   'Academy of Technology',
#   2021,
#   'CSE',
#   '',
#   '',
#   '',
#   'https://www.linkedin.com/in/srinjoy-chowdhury-44a35713b',
#   '',
#   'U010RRQNNGK'),
#  (80,
#   3,
#   'Rahul',
#   'Ghosh',
#   'rahulghosh813@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image80.jpg',
#   'Academy Of Technology',
#   2021,
#   'CSE',
#   '',
#   '',
#   '',
#   'https://www.linkedin.com/in/rahul-ghosh-432852175/',
#   '',
#   'U010RRQQA8K'),
#  (81,
#   3,
#   'SHUBHOBRATA',
#   'DAS',
#   'shubhobrata.das@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Future Institute Of Engineering and Management',
#   2021,
#   'CSE',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'U010T9HMXL1'),
#  (83,
#   3,
#   'Sanaa',
#   'Yousuf',
#   'sanaayousuf495@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image83.jpeg',
#   'Calcutta institute of engineering and management',
#   2015,
#   'CSE',
#   'https://github.com/Sanaa495',
#   'https://medium.com/@sanaayousuf495/data-science-data-analytics-data-engineering-and-machine-learning-are-growing-at-an-fcd7fbf2bba',
#   'https://sites.google.com/view/sanaayousuf/home?authuser=0',
#   'https://www.linkedin.com/in/sanaa-yousuf-41084a190',
#   'CdyCkHUNras',
#   'U0112R9BV4L'),
#  (84,
#   3,
#   'Madhuparna',
#   'Majumdar',
#   'madhuparna299@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image84.jpg',
#   'Calcutta Institute of Engineering and Management',
#   2021,
#   'IT',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'U01156TJQ8N'),
#  (85,
#   3,
#   'Sarthak',
#   'Kundu',
#   'kundus101@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Techno Main',
#   2022,
#   'EE',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'U010RRQGB8B'),
#  (86,
#   3,
#   'Banti',
#   'Pandey',
#   'bantipandey95@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'U010T9HSS9X'),
#  (87,
#   3,
#   'Alekhyo',
#   'Banerjee',
#   'alex26062000@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'RCC Institute of Information Technology',
#   2022,
#   'CSE',
#   'https://github.com/Alekhyo',
#   'https://medium.com/@alex26062000',
#   'https://sites.google.com/view/abanerjee/home',
#   'https://www.linkedin.com/in/alekhyobanerjee/',
#   'Ry6a-Wm-XBE',
#   'U0113A91R7A'),
#  (88,
#   3,
#   'Satyaki',
#   'Saha',
#   'satyakisaha726@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Future Institute Of Engineering And Management ',
#   2015,
#   'CSE',
#   'https://github.com/satyaki726',
#   '',
#   '',
#   'https://www.linkedin.com/in/satyaki-saha-284b2219b',
#   '',
#   'U0112R9BCUU'),
#  (89,
#   3,
#   'Rima',
#   'Kar',
#   'rimakar2017@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image89.jpg',
#   'Netaji Subhash Engineering college',
#   2021,
#   'ECE',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'U010RRQKK6F'),
#  (90,
#   3,
#   'Ritayan',
#   'Dhara',
#   'dhararitayan@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'U01156TDA6S'),
#  (93,
#   3,
#   'Writuparna',
#   'Banerjee',
#   'writuparnabanerjee@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image93.jpg',
#   'SVIST',
#   2015,
#   'CSE',
#   '',
#   '',
#   'https://sites.google.com/view/writuparnabanerjee',
#   'https://www.linkedin.com/in/writuparna-banerjee-b9193416b',
#   '',
#   'U010T9HJG0H'),
#  (94,
#   3,
#   'Rahul',
#   'Shaw',
#   'imyuvi497@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image94.jpg',
#   'Academy of Technology',
#   2022,
#   'ME',
#   '',
#   '',
#   '',
#   'https://www.linkedin.com/in/rahul-shaw-2460a11a0',
#   '',
#   'U010T9J063B'),
#  (95,
#   3,
#   'RAHUL',
#   'SINGH',
#   '08rahul.singh311@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'ACADEMY OF TECHNOLOGY',
#   2022,
#   'ME',
#   '',
#   '',
#   '',
#   'https://www.linkedin.com/in/rahul-singh-3a2707189',
#   '',
#   'U01156U0HM4'),
#  (96,
#   3,
#   'Srijani',
#   'Chaudhury',
#   'chaudhurysrijani@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image96.jpeg',
#   'Bp Poddar Institute Of Management and Technology',
#   2023,
#   'ECE',
#   'https://github.com/Srijani-Chaudhury',
#   'https://medium.com/@chaudhurysrijani',
#   'https://sites.google.com/view/srijanichaudhury/home',
#   'https://www.linkedin.com/in/srijani-chaudhury-726851192',
#   'UYzhNOBdCp4',
#   'U0113A9G8DN'),
#  (98,
#   3,
#   'Om',
#   'Prakash Shaw',
#   'omprakash2517@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'U01138N9U5T'),
#  (101,
#   3,
#   'Sankha Subhra',
#   'Mondal',
#   'sankhasubhramondal178@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'SVIST',
#   2021,
#   'EEE',
#   'https://github.com/Sankha1998',
#   'https://medium.com/@sankhasubhramondal18',
#   'https://sankhasubhramondal.com',
#   'https://www.linkedin.com/in/sankha-subhra-mondal-540133168',
#   '',
#   'U010QH2LGG2'),
#  (102,
#   3,
#   'Mushrequa',
#   'Nawaz',
#   'mushrequanawaz@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Amity University',
#   2021,
#   'CSE',
#   '',
#   '',
#   '',
#   'https://www.linkedin.com/in/mushrequa-nawaz-a3b1881a0/',
#   '',
#   'U010RRR6XPD'),
#  (103,
#   3,
#   'Rajrupa',
#   'Mitra',
#   'rajbeadon@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   'Neotia institute of technology management and science',
#   2022,
#   'ECE',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'U010QH2M150'),
#  (104,
#   3,
#   'Priscila',
#   'Tamang Ghising',
#   'iampris7@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/default.png',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'U01156U26TG'),
#  (105,
#   3,
#   'GAZAL',
#   'GARG',
#   'gazalgarg2298@gmail.com',
#   '',
#   'https://campus-x-profile-images.s3.ap-south-1.amazonaws.com/image105.jpg',
#   'Amity University kolkata ',
#   2021,
#   'CSE',
#   '',
#   '',
#   '',
#   'https://www.linkedin.com/in/gazal-garg-073a2719b',
#   '',
#   'U0115B5AWRM'),
#  (106,
#   3,
#   'Suman',
#   'Bhunia',
#   'sumankumarbhunia98@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'U0113A9J4SU'),
#  (107,
#   4,
#   'Ujjainee',
#   'De',
#   'ujjaineede@gmail.com',
#   '',
#   '',
#   'Amity University Kolkata',
#   2021,
#   'CSE',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'NA'),
#  (108,
#   4,
#   'Surabhi ',
#   'Basak',
#   'imsurabhi2@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (109,
#   4,
#   'Kunal',
#   'Gohrani',
#   'gohrani.kunal8@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (110,
#   4,
#   'Shushree',
#   'Siddhishika',
#   'bsarojk@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (112,
#   4,
#   'Bhavna',
#   'Gupta',
#   'bhavnaphotos12@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (113,
#   4,
#   'Shakib',
#   'Mondal',
#   'shakibmondal1998@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (114,
#   4,
#   'Vishal',
#   'Malo',
#   'vishalmalo.cse@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (115,
#   4,
#   'Purbita',
#   'Sur',
#   'gsur2012@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (116,
#   4,
#   'Anjali',
#   'K',
#   'anjaliks2598@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (117,
#   4,
#   'Shantanu',
#   'Shubham',
#   'shantanushubham18@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (118,
#   4,
#   'Durga',
#   'Agarwal',
#   'durgaag.uemk@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (119,
#   4,
#   'Kaushal',
#   'Agarwal',
#   'kaushal.kkr@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (121,
#   4,
#   'Dipam',
#   'Hazra',
#   'mynameisdipam@gmail.com',
#   '',
#   '',
#   '',
#   0,
#   '',
#   '',
#   '',
#   '',
#   '',
#   None,
#   'NA'),
#  (122,
#   4,
#   'Prasoon',
#   'Thakur',
#   'prasoonkumar27@gmail.com',
#   '',
#   '',
#   'Guru Nanak Institute of Technology (GNIT)',
#   2021,
#   'IT',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'NA')]
